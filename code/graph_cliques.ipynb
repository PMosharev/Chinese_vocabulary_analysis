# %%
import networkx as nx
from functions import *
import matplotlib.pyplot as plt

# %%
foldername = '../data/Official_HSK/'
from_level = 1
to_level = 4
filenames = create_filename_list(foldername=foldername, from_level=from_level, to_level=to_level)

# %%
list_of_all_words = []
for filename in filenames:
    list_of_all_words += csv_to_list_of_words(filename)

# %%
graph = nx.Graph()
for w in list_of_all_words:
    if len(w.chinese) == 2 and w.chinese[0] != w.chinese[1]:
        graph.add_edge(w.chinese[0].encode('utf8').decode('utf8'), w.chinese[1].encode('utf8').decode('utf8'))

# %%
labels = {i: n for i, n in enumerate(graph.nodes())}
mapping = {n: i for i, n in enumerate(graph.nodes())}

nx.relabel_nodes(graph, mapping, copy=False)

# %%
chinese_to_word = {w.chinese: w for w in list_of_all_words}

# %%
cliques = nx.find_cliques(graph)
all_words_from_cliques = []

for clique in sorted(list(cliques), key=lambda x: len(x), reverse=True):
    if len(clique) > 2:
        # print('=========================')
        this_subgraph = nx.subgraph(graph, clique)
        words_here = []
        for edge in this_subgraph.edges:
            chinese1 = labels[edge[0]] + labels[edge[1]]
            chinese2 = labels[edge[1]] + labels[edge[0]]
            if chinese1 in chinese_to_word:
                # print(word_to_string(chinese_to_word[chinese1]))
                words_here.append(chinese_to_word[chinese1])
            if chinese2 in chinese_to_word:
                # print(word_to_string(chinese_to_word[chinese2]))
                words_here.append(chinese_to_word[chinese2])
        all_words_from_cliques.append(words_here)

print('All cliques found in the graph:')
for cl in sorted(all_words_from_cliques, key = lambda x: len(x), reverse=True):
    print('=========================')
    for w in cl:
        print(word_to_string(w))
# Out:
# All cliques found in the graph:
# =========================
# 爱情    	 [àiqíng] - 	Love
# 爱心    	 [àixīn] - 	love
# 热爱    	 [rè’ài] - 	Ardently love
# 热情    	 [rèqíng] - 	Enthusiasm
# 热心    	 [rèxīn] - 	enthusiastic
# 心情    	 [xīnqíng] - 	mood
# =========================
# 年初    	 [nián chū] - 	beginning of the year
# 初中    	 [chū zhōng] - 	junior high school
# 初级    	 [chūjí] - 	primary
# 中年    	 [zhōng nián] - 	middle age,  middle-aged
# 中级    	 [zhōng jí] - 	intermediate,  middle-level
# 年级    	 [niánjí] - 	grade
# =========================
# 东北    	 [dōng běi] - 	northeast
# 东西    	 [dōngxi] - 	thing
# 东部    	 [dōng bù] - 	east
# 西北    	 [xī běi] - 	northwest
# 西部    	 [xī bù] - 	west
# 北部    	 [běi bù] - 	north
# =========================
# 东北    	 [dōng běi] - 	northeast
# 东方    	 [dōng fāng] - 	east
# 东西    	 [dōngxi] - 	thing
# 西北    	 [xī běi] - 	northwest
# 西方    	 [xī fāng] - 	west
# 北方    	 [běifāng] - 	north
# =========================
# 东北    	 [dōng běi] - 	northeast
# 东边    	 [dōng biān] - 	east side
# 东西    	 [dōngxi] - 	thing
# 西北    	 [xī běi] - 	northwest
# 西边    	 [xī biān] - 	west,  west side
# 北边    	 [běi biān] - 	North side
# =========================
# 东边    	 [dōng biān] - 	east side
# 东西    	 [dōngxi] - 	thing
# 东南    	 [dōng nán] - 	southeast
# 西边    	 [xī biān] - 	west,  west side
# 西南    	 [xī nán] - 	southwest
# 南边    	 [nán biān] - 	south,  south side
# =========================
# 男人    	 [nán ren] - 	man
# 人生    	 [rénshēng] - 	Life
# 女人    	 [nǚ ren] - 	woman
# 男女    	 [nán nǚ] - 	men and women,  male and female
# 女生    	 [nǚ shēng] - 	girl
# 男生    	 [nán shēng] - 	boy
# =========================
# 东方    	 [dōng fāng] - 	east
# 东西    	 [dōngxi] - 	thing
# 东南    	 [dōng nán] - 	southeast
# 西方    	 [xī fāng] - 	west
# 南方    	 [nán fāng] - 	south
# 西南    	 [xī nán] - 	southwest
# =========================
# 东西    	 [dōngxi] - 	thing
# 东南    	 [dōng nán] - 	southeast
# 东部    	 [dōng bù] - 	east
# 西南    	 [xī nán] - 	southwest
# 西部    	 [xī bù] - 	west
# 南部    	 [nán bù] - 	south
# =========================
# 儿子    	 [érzi] - 	Son
# 子女    	 [zǐ nǚ] - 	child,  sons and daughters
# 女子    	 [nǚ zǐ] - 	woman,  female
# 女儿    	 [nǚ’ér] - 	daughter
# =========================
# 男子    	 [nán zǐ] - 	man,  male
# 子女    	 [zǐ nǚ] - 	child,  sons and daughters
# 女子    	 [nǚ zǐ] - 	woman,  female
# 男女    	 [nán nǚ] - 	men and women,  male and female
# =========================
# 子女    	 [zǐ nǚ] - 	child,  sons and daughters
# 女子    	 [nǚ zǐ] - 	woman,  female
# 孙子    	 [sūnzi] - 	Grandson
# 孙女    	 [sūn nǚ] - 	granddaughter
# =========================
# 大人    	 [dà rén] - 	adult
# 人家    	 [rénjiā] - 	family
# 家人    	 [jiā rén] - 	family
# 大家    	 [dàjiā] - 	everybody
# =========================
# 工人    	 [gōngrén] - 	Worker
# 人工    	 [réngōng] - 	artificial
# 员工    	 [yuángōng] - 	employee
# 人员    	 [rényuán] - 	personnel
# =========================
# 工人    	 [gōngrén] - 	Worker
# 人工    	 [réngōng] - 	artificial
# 工夫    	 [gōng fu] - 	time
# 夫人    	 [fūrén] - 	Madam
# =========================
# 人家    	 [rénjiā] - 	family
# 家人    	 [jiā rén] - 	family
# 老人    	 [lǎo rén] - 	old people,  the aged
# 老家    	 [lǎo jiā] - 	hometown,  home state
# =========================
# 对方    	 [duìfāng] - 	Other party
# 方面    	 [fāngmiàn] - 	Aspect
# 对面    	 [duìmiàn] - 	Opposite side
# 面对    	 [miànduì] - 	Face
# =========================
# 出现    	 [chūxiàn] - 	Appear
# 发现    	 [fāxiàn] - 	find
# 发出    	 [fā chū] - 	issue,  send out,  give off,  emit
# 出发    	 [chūfā] - 	Set out
# =========================
# 发出    	 [fā chū] - 	issue,  send out,  give off,  emit
# 出发    	 [chūfā] - 	Set out
# 发生    	 [fāshēng] - 	Happen
# 出生    	 [chūshēng] - 	Birth
# =========================
# 开发    	 [kāifā] - 	Development
# 发展    	 [fāzhǎn] - 	Development
# 开展    	 [kāizhǎn] - 	Develop
# 展开    	 [zhǎnkāi] - 	Open
# =========================
# 前后    	 [qián hòu] - 	front and back,  from start to finish,  around
# 前面    	 [qiánmiàn] - 	Front
# 面前    	 [miàn qián] - 	in front of,  before
# 后面    	 [hòumiàn] - 	behind
# =========================
# 现在    	 [xiànzài] - 	Now
# 现实    	 [xiànshí] - 	reality
# 实现    	 [shíxiàn] - 	Realization
# 实在    	 [shízai] - 	done carefully
# =========================
# 爱人    	 [ài rén] - 	lover
# 亲爱    	 [qīn’ài] - 	Dear
# 亲人    	 [qīn rén] - 	relative
# =========================
# 爱好    	 [ài hào] - 	hobby
# 爱人    	 [ài rén] - 	lover
# 好人    	 [hǎo rén] - 	good person
# =========================
# 好多    	 [hǎo duō] - 	many,  a lot of
# 好久    	 [hǎo jiǔ] - 	for a long time,  long
# 多久    	 [duō jiǔ] - 	how long
# =========================
# 明白    	 [míngbai] - 	clear
# 明天    	 [míngtiān] - 	Tomorrow
# 白天    	 [bái tiān] - 	day
# =========================
# 天气    	 [tiānqì] - 	weather
# 天空    	 [tiānkōng] - 	sky
# 空气    	 [kōngqì] - 	atmosphere
# =========================
# 前天    	 [qián tiān] - 	the day before yesterday
# 前后    	 [qián hòu] - 	front and back,  from start to finish,  around
# 后天    	 [hòu tiān] - 	day after tomorrow
# =========================
# 后天    	 [hòu tiān] - 	day after tomorrow
# 今天    	 [jīntiān] - 	Today
# 今后    	 [jīn hòu] - 	from now on,  in the future
# =========================
# 前年    	 [qián nián] - 	the year before last
# 前后    	 [qián hòu] - 	front and back,  from start to finish,  around
# 后年    	 [hòu nián] - 	the year after next
# =========================
# 少年    	 [shào nián] - 	juvenile,  young person
# 多少    	 [duōshao] - 	how much
# 多年    	 [duō nián] - 	many years
# =========================
# 中年    	 [zhōng nián] - 	middle age,  middle-aged
# 中学    	 [zhōng xué] - 	middle school
# 学年    	 [xué nián] - 	school year,  academic year
# =========================
# 今年    	 [jīn nián] - 	this year
# 今后    	 [jīn hòu] - 	from now on,  in the future
# 后年    	 [hòu nián] - 	the year after next
# =========================
# 房子    	 [fáng zi] - 	house,  building
# 屋子    	 [wūzi] - 	House
# 房屋    	 [fáng wū] - 	houses,  buildings,  tenement
# =========================
# 椅子    	 [yǐzi] - 	Chair
# 轮子    	 [lún zi] - 	wheel
# 轮椅    	 [lún yǐ] - 	wheelchair
# =========================
# 里边    	 [lǐ biān] - 	inside
# 那里    	 [nà lǐ] - 	there
# 那边    	 [nà biān] - 	there
# =========================
# 里边    	 [lǐ biān] - 	inside
# 这里    	 [zhè lǐ] - 	here
# 这边    	 [zhè biān] - 	here
# =========================
# 右边    	 [yòubian] - 	Right
# 左右    	 [zuǒyòu] - 	About
# 左边    	 [zuǒbian] - 	left
# =========================
# 前边    	 [qián biān] - 	in front
# 前后    	 [qián hòu] - 	front and back,  from start to finish,  around
# 后边    	 [hòu biān] - 	behind,  back
# =========================
# 路边    	 [lù biān] - 	roadside,  wayside
# 路上    	 [lù shàng] - 	on the road
# 上边    	 [shàng biān] - 	above,  on
# =========================
# 身边    	 [shēn biān] - 	at [by] one’s side
# 身上    	 [shēn shàng] - 	body,  on one’s body
# 上边    	 [shàng biān] - 	above,  on
# =========================
# 别人    	 [bié·rén] - 	other people
# 个人    	 [gèrén] - 	personal
# 个别    	 [gèbié] - 	individual
# =========================
# 性别    	 [xìngbié] - 	Gender
# 个性    	 [gèxìng] - 	personality
# 个别    	 [gèbié] - 	individual
# =========================
# 成人    	 [chéngrén] - 	adult
# 熟人    	 [shú rén] - 	acquaintance
# 成熟    	 [chéngshú] - 	mature
# =========================
# 大人    	 [dà rén] - 	adult
# 夫人    	 [fūrén] - 	Madam
# 大夫    	 [dàifu] - 	Doctor
# =========================
# 成人    	 [chéngrén] - 	adult
# 人员    	 [rényuán] - 	personnel
# 成员    	 [chéngyuán] - 	member
# =========================
# 有人    	 [yǒu rén] - 	someone,  there’s someone
# 有名    	 [yǒumíng] - 	Famous
# 名人    	 [míng rén] - 	celebrity,  famous person
# =========================
# 主人    	 [zhǔrén] - 	master
# 主动    	 [zhǔdòng] - 	active
# 动人    	 [dòng rén] - 	moving,  touching
# =========================
# 行人    	 [xíngrén] - 	pedestrian
# 行动    	 [xíngdòng] - 	Get some action
# 动人    	 [dòng rén] - 	moving,  touching
# =========================
# 病人    	 [bìng rén] - 	patient
# 人生    	 [rénshēng] - 	Life
# 生病    	 [shēngbìng] - 	Fall ill
# =========================
# 动人    	 [dòng rén] - 	moving,  touching
# 人生    	 [rénshēng] - 	Life
# 生动    	 [shēngdòng] - 	vivid
# =========================
# 不然    	 [bùrán] - 	otherwise
# 必然    	 [bìrán] - 	Inevitable
# 不必    	 [bú bì] - 	need not,  not have to
# =========================
# 不要    	 [bú yào] - 	don’t
# 不必    	 [bú bì] - 	need not,  not have to
# 必要    	 [bìyào] - 	necessary
# =========================
# 大量    	 [dà liàng] - 	a lot of,  lots of
# 重量    	 [zhòngliàng] - 	weight
# 重大    	 [zhòngdà] - 	significant
# =========================
# 大会    	 [dà huì] - 	convention,  general meeting,  General Assembly
# 约会    	 [yuēhuì] - 	Date
# 大约    	 [dàyuē] - 	about
# =========================
# 大型    	 [dàxíng] - 	large
# 小型    	 [xiǎo xíng] - 	small-size,  small-scale
# 大小    	 [dà xiǎo] - 	size
# =========================
# 大声    	 [dà shēng] - 	loud
# 小声    	 [xiǎo shēng] - 	in a low voice,  in whispers
# 大小    	 [dà xiǎo] - 	size
# =========================
# 大姐    	 [dà jiě] - 	elder sister
# 小姐    	 [xiǎojiě] - 	Miss
# 大小    	 [dà xiǎo] - 	size
# =========================
# 大小    	 [dà xiǎo] - 	size
# 小学    	 [xiǎo xué] - 	primary school,  elementary schoo
# 大学    	 [dà xué] - 	university
# =========================
# 长大    	 [zhǎng dà] - 	grow up
# 家长    	 [jiā zhǎng] - 	parent,  the head of the family
# 大家    	 [dàjiā] - 	everybody
# =========================
# 对方    	 [duìfāng] - 	Other party
# 方针    	 [fāngzhēn] - 	policy
# 针对    	 [zhēnduì] - 	In the light of
# =========================
# 适用    	 [shì yòng] - 	be applicable,  be suitable
# 适应    	 [shìyìng] - 	Adapt
# 应用    	 [yìngyòng] - 	application
# =========================
# 有用    	 [yǒu yòng] - 	useful
# 有利    	 [yǒulì] - 	favourable,  beneficial
# 利用    	 [lìyòng] - 	utilize
# =========================
# 有用    	 [yǒu yòng] - 	useful
# 没有    	 [méi yǒu] - 	have not,  no
# 没用    	 [méi yòng] - 	useless
# =========================
# 打车    	 [dǎ chē] - 	take a taxi
# 开车    	 [kāi chē] - 	drive,  drive a car
# 打开    	 [dǎ kāi] - 	turn on
# =========================
# 下车    	 [xià chē] - 	get off
# 停下    	 [tíng xià] - 	stop
# 停车    	 [tíng chē] - 	park
# =========================
# 上来    	 [shàng lái] - 	come up
# 以来    	 [yǐlái] - 	Since
# 以上    	 [yǐ shàng] - 	above,  over
# =========================
# 地上    	 [dì shàng] - 	on the ground
# 地面    	 [dì miàn] - 	ground,  floor,  surface
# 上面    	 [shàng miàn] - 	above,  on top of
# =========================
# 马上    	 [mǎshàng] - 	Right off
# 马路    	 [mǎ lù] - 	road,  street
# 路上    	 [lù shàng] - 	on the road
# =========================
# 认出    	 [rèn chū] - 	recognize,  identify,  make out
# 认得    	 [rèn dé] - 	know,  recognize
# 得出    	 [dé chū] - 	obtain results,  reach conclusion
# =========================
# 出口    	 [chūkǒu] - 	Exit
# 门口    	 [mén kǒu] - 	doorway
# 出门    	 [chū mén] - 	go out
# =========================
# 从来    	 [cónglái] - 	Always
# 来自    	 [láizì] - 	Come from
# 自从    	 [zìcóng] - 	Since
# =========================
# 来到    	 [lái dào] - 	come,  arrive
# 回来    	 [huí lái] - 	come back,  return
# 回到    	 [huí dào] - 	back to
# =========================
# 来到    	 [lái dào] - 	come,  arrive
# 看来    	 [kàn lái] - 	it seems,  it appears
# 看到    	 [kàn dào] - 	see
# =========================
# 下来    	 [xià lái] - 	come down,  get down
# 以来    	 [yǐlái] - 	Since
# 以下    	 [yǐ xià] - 	below,  under
# =========================
# 后来    	 [hòulái] - 	later
# 以来    	 [yǐlái] - 	Since
# 以后    	 [yǐ hòu] - 	after,  later on,  afterwards,  later
# =========================
# 开机    	 [kāi jī] - 	starting up
# 机会    	 [jīhuì] - 	Opportunity
# 开会    	 [kāi huì] - 	have a meeting
# =========================
# 开心    	 [kāixīn] - 	Happy
# 放心    	 [fàngxīn] - 	Don’t worry
# 开放    	 [kāifàng] - 	To open up
# =========================
# 分开    	 [fēn kāi] - 	separate,  part
# 学分    	 [xué fēn] - 	credit,  academic credit
# 开学    	 [kāi xué] - 	school opens,  term begins
# =========================
# 开放    	 [kāifàng] - 	To open up
# 放学    	 [fàng xué] - 	off school
# 开学    	 [kāi xué] - 	school opens,  term begins
# =========================
# 球队    	 [qiú duì] - 	team
# 排队    	 [páiduì] - 	queue,  stand in a line
# 排球    	 [pái qiú] - 	volleyball
# =========================
# 球场    	 [qiú chǎng] - 	court,  field
# 全场    	 [quán chǎng] - 	the whole audience
# 全球    	 [quán qiú] - 	global,  the whole world
# =========================
# 同学    	 [tóngxué] - 	Classmate
# 同时    	 [tóngshí] - 	meanwhile
# 学时    	 [xué shí] - 	class hour,  period
# =========================
# 中学    	 [zhōng xué] - 	middle school
# 中文    	 [zhōngwén] - 	Chinese
# 文学    	 [wénxué] - 	literature
# =========================
# 小学    	 [xiǎo xué] - 	primary school,  elementary schoo
# 小时    	 [xiǎoshí] - 	hour
# 学时    	 [xué shí] - 	class hour,  period
# =========================
# 中学    	 [zhōng xué] - 	middle school
# 期中    	 [qī zhōng] - 	midterm
# 学期    	 [xuéqī] - 	Semester
# =========================
# 中学    	 [zhōng xué] - 	middle school
# 中医    	 [zhōng yī] - 	Chinese Medicine
# 医学    	 [yī xué] - 	medical science,  medicine
# =========================
# 学院    	 [xué yuàn] - 	college,  academy
# 医院    	 [yīyuàn] - 	Hospital
# 医学    	 [yī xué] - 	medical science,  medicine
# =========================
# 学生    	 [xuésheng] - 	Student
# 医生    	 [yīshēng] - 	Doctor
# 医学    	 [yī xué] - 	medical science,  medicine
# =========================
# 取得    	 [qǔ dé] - 	acquire,  gain,  obtain
# 获取    	 [huò qǔ] - 	gain,  obtain
# 获得    	 [huòdé] - 	Get
# =========================
# 感到    	 [gǎn dào] - 	feel,  sense
# 感受    	 [gǎnshòu] - 	feel
# 受到    	 [shòudào] - 	Suffer
# =========================
# 回到    	 [huí dào] - 	back to
# 收回    	 [shōu huí] - 	withdraw,  regain,  call in,  countermand
# 收到    	 [shōu dào] - 	receive,  obtain
# =========================
# 收到    	 [shōu dào] - 	receive,  obtain
# 收看    	 [shōu kàn] - 	watch
# 看到    	 [kàn dào] - 	see
# =========================
# 收到    	 [shōu dào] - 	receive,  obtain
# 收听    	 [shōu tīng] - 	listen to,  listen in
# 听到    	 [tīng dào] - 	hear
# =========================
# 直到    	 [zhí dào] - 	until
# 直接    	 [zhíjiē] - 	direct
# 接到    	 [jiē dào] - 	receive
# =========================
# 受到    	 [shòudào] - 	Suffer
# 接受    	 [jiēshòu] - 	accept
# 接到    	 [jiē dào] - 	receive
# =========================
# 见到    	 [jiàn dào] - 	see
# 碰见    	 [pèng jiàn] - 	meet,  run into,  bump into
# 碰到    	 [pèng dào] - 	meet,  run into,  bump into
# =========================
# 见到    	 [jiàn dào] - 	see
# 看见    	 [kànjiàn] - 	seeing
# 看到    	 [kàn dào] - 	see
# =========================
# 见到    	 [jiàn dào] - 	see
# 遇见    	 [yù jiàn] - 	meet,  come across
# 遇到    	 [yùdào] - 	encounter
# =========================
# 见到    	 [jiàn dào] - 	see
# 听见    	 [tīng jiàn] - 	hear
# 听到    	 [tīng dào] - 	hear
# =========================
# 地面    	 [dì miàn] - 	ground,  floor,  surface
# 地下    	 [dì xià] - 	underground,  subterranean,  secret
# 下面    	 [xià miàn] - 	below,  under,  next
# =========================
# 地方    	 [dìfang] - 	local
# 地面    	 [dì miàn] - 	ground,  floor,  surface
# 方面    	 [fāngmiàn] - 	Aspect
# =========================
# 外地    	 [wài dì] - 	other places,  nonlocal
# 地面    	 [dì miàn] - 	ground,  floor,  surface
# 外面    	 [wài miàn] - 	outside,  outdoors,  outward appearance
# =========================
# 地位    	 [dìwèi] - 	status
# 各地    	 [gè dì] - 	various regions,  everywhere
# 各位    	 [gè wèi] - 	everybody
# =========================
# 方法    	 [fāngfǎ] - 	Method
# 官方    	 [guānfāng] - 	by the government official
# 法官    	 [fǎ guān] - 	judge
# =========================
# 电影    	 [diànyǐng] - 	Film
# 影视    	 [yǐng shì] - 	film and television
# 电视    	 [diànshì] - 	television
# =========================
# 移动    	 [yídòng] - 	move
# 转移    	 [zhuǎnyí] - 	transfer
# 转动    	 [zhuǎn dòng] - 	turn,  move,  turn round
# =========================
# 活动    	 [huódòng] - 	activity
# 生活    	 [shēnghuó] - 	Life
# 生动    	 [shēngdòng] - 	vivid
# =========================
# 主动    	 [zhǔdòng] - 	active
# 自主    	 [zìzhǔ] - 	Autonomy
# 自动    	 [zìdòng] - 	automatic
# =========================
# 生动    	 [shēngdòng] - 	vivid
# 发动    	 [fādòng] - 	Launch
# 发生    	 [fāshēng] - 	Happen
# =========================
# 工作    	 [gōngzuò] - 	work
# 工业    	 [gōngyè] - 	Industry
# 作业    	 [zuòyè] - 	task, homework
# =========================
# 作业    	 [zuòyè] - 	task, homework
# 创作    	 [chuàngzuò] - 	A literary creation
# 创业    	 [chuàngyè] - 	carve out
# =========================
# 多少    	 [duōshao] - 	how much
# 少数    	 [shǎo shù] - 	small number,  few,  minority
# 多数    	 [duō shù] - 	most,  majority
# =========================
# 中间    	 [zhōngjiān] - 	Middle
# 期中    	 [qī zhōng] - 	midterm
# 期间    	 [qījiān] - 	Period
# =========================
# 关机    	 [guān jī] - 	shutdown
# 相机    	 [xiàng jī] - 	camera
# 相关    	 [xiāngguān] - 	correlate
# =========================
# 高中    	 [gāo zhōng] - 	senior high school
# 中级    	 [zhōng jí] - 	intermediate,  middle-level
# 高级    	 [gāojí] - 	senior
# =========================
# 工业    	 [gōngyè] - 	Industry
# 职工    	 [zhí gōng] - 	staff,  worker
# 职业    	 [zhíyè] - 	Occupation
# =========================
# 回国    	 [huí guó] - 	return home from abroad
# 回家    	 [huí jiā] - 	go home,  return home
# 国家    	 [guójiā] - 	Country
# =========================
# 国家    	 [guójiā] - 	Country
# 全国    	 [quán guó] - 	nationwide,  entire country
# 全家    	 [quán jiā] - 	whole family
# =========================
# 要是    	 [yàoshi] - 	If
# 就要    	 [jiù yào] - 	be going to,  be about to
# 就是    	 [jiù shì] - 	precisely,  exactly,  just like
# =========================
# 要是    	 [yàoshi] - 	If
# 只要    	 [zhǐyào] - 	as long as
# 只是    	 [zhǐ shì] - 	merely,  only,  just
# =========================
# 然后    	 [ránhòu] - 	Then
# 果然    	 [guǒrán] - 	Sure enough
# 后果    	 [hòuguǒ] - 	Consequence
# =========================
# 前后    	 [qián hòu] - 	front and back,  from start to finish,  around
# 之前    	 [zhī qián] - 	before,  prior to
# 之后    	 [zhī hòu] - 	later,  after,  afterwards
# =========================
# 前后    	 [qián hòu] - 	front and back,  from start to finish,  around
# 前头    	 [qián tou] - 	front,  thereinbefore
# 后头    	 [hòu tou] - 	back
# =========================
# 前后    	 [qián hòu] - 	front and back,  from start to finish,  around
# 以前    	 [yǐqián] - 	before
# 以后    	 [yǐ hòu] - 	after,  later on,  afterwards,  later
# =========================
# 记录    	 [jìlù] - 	Record
# 登录    	 [dēnglù] - 	Sign in
# 登记    	 [dēngjì] - 	register
# =========================
# 进口    	 [jìnkǒu] - 	Imported
# 入口    	 [rùkǒu] - 	Entrance
# 进入    	 [jìn rù] - 	enter,  go in,  join
# =========================
# 进行    	 [jìnxíng] - 	Conduct
# 步行    	 [bù xíng] - 	go on foot,  walk
# 进步    	 [jìnbù] - 	progress
# =========================
# 考试    	 [kǎoshì] - 	Examination
# 考验    	 [kǎoyàn] - 	test
# 试验    	 [shìyàn] - 	test
# =========================
# 表明    	 [biǎomíng] - 	Indicate
# 发明    	 [fāmíng] - 	Invention
# 发表    	 [fābiǎo] - 	Publish
# =========================
# 长期    	 [cháng qī] - 	over a long period of time,  long-term
# 延长    	 [yáncháng] - 	extend
# 延期    	 [yánqī] - 	Delay
# =========================
# 中午    	 [zhōngwǔ] - 	Noon
# 午餐    	 [wǔ cān] - 	lunch
# 中餐    	 [zhōng cān] - 	Chinese food
# =========================
# 身体    	 [shēntǐ] - 	body
# 全身    	 [quán shēn] - 	whole body
# 全体    	 [quán tǐ] - 	all,  entire,  whole
# =========================
# 个体    	 [gètǐ] - 	individual
# 整体    	 [zhěngtǐ] - 	Whole
# 整个    	 [zhěnggè] - 	Whole
# =========================
# 气温    	 [qì wēn] - 	air temperature
# 暖气    	 [nuǎn qì] - 	central heating,  heating,  heater
# 温暖    	 [wēnnuǎn] - 	warm
# =========================
# 结果    	 [jiéguǒ] - 	Result
# 果实    	 [guǒshí] - 	fruit
# 结实    	 [jiēshi] - 	strong
# =========================
# 同情    	 [tóngqíng] - 	Sympathy
# 同事    	 [tóngshì] - 	Colleague
# 事情    	 [shìqing] - 	Thing
# =========================
# 表现    	 [biǎoxiàn] - 	performance
# 现代    	 [xiàndài] - 	modern
# 代表    	 [dàibiǎo] - 	representative
# =========================
# 表现    	 [biǎoxiàn] - 	performance
# 发现    	 [fāxiàn] - 	find
# 发表    	 [fābiǎo] - 	Publish
# =========================
# 初中    	 [chū zhōng] - 	junior high school
# 当初    	 [dāngchū] - 	Original
# 当中    	 [dāng zhōng] - 	among,  in the middle,  in the centre
# =========================
# 需要    	 [xūyào] - 	Need
# 需求    	 [xūqiú] - 	demand
# 要求    	 [yāoqiú] - 	Requirement
# =========================
# 安静    	 [ānjìng] - 	Be quiet
# 平安    	 [píng’ān] - 	sound and safe
# 平静    	 [píngjìng] - 	calm
# =========================
# 安置    	 [ānzhì] - 	put,  arrange for
# 装置    	 [zhuāng zhì] - 	device,  equipment
# 安装    	 [ānzhuāng] - 	install
# =========================
# 成长    	 [chéngzhǎng] - 	Grow up
# 组长    	 [zǔ zhǎng] - 	group leader
# 组成    	 [zǔchéng] - 	Form
# =========================
# 市长    	 [shì zhǎng] - 	mayor
# 长城    	 [Chángchéng] - 	The Great Wall
# 城市    	 [chéngshì] - 	City
# =========================
# 比如    	 [bǐrú] - 	such as
# 比例    	 [bǐlì] - 	Proportion
# 例如    	 [lìrú] - 	for example
# =========================
# 变为    	 [biàn wéi] - 	become,  turn into,  change into
# 成为    	 [chéngwéi] - 	Become
# 变成    	 [biàn chéng] - 	become,  change into
# =========================
# 建成    	 [jiàn chéng] - 	built up
# 建立    	 [jiànlì] - 	establish
# 成立    	 [chénglì] - 	establish
# =========================
# 造成    	 [zàochéng] - 	cause
# 构造    	 [gòu zào] - 	structure,  construction
# 构成    	 [gòuchéng] - 	constitute
# =========================
# 表达    	 [biǎodá] - 	Expression
# 发达    	 [fādá] - 	developed
# 发表    	 [fābiǎo] - 	Publish
# =========================
# 度过    	 [dùguò] - 	Spend
# 难度    	 [nán dù] - 	difficulty
# 难过    	 [nánguò] - 	Sorry
# =========================
# 度过    	 [dùguò] - 	Spend
# 程度    	 [chéngdù] - 	degree
# 过程    	 [guòchéng] - 	process
# =========================
# 春季    	 [chūn jì] - 	spring,  springtime
# 季节    	 [jìjié] - 	Season
# 春节    	 [chūn jié] - 	Spring Festival,  Chinese New Year
# =========================
# 力量    	 [lìliàng] - 	Power
# 尽量    	 [jǐnliàng] - 	as far as possible
# 尽力    	 [jìnlì] - 	Try the best
# =========================
# 旅客    	 [lǚ kè] - 	passenger,  traveler
# 旅游    	 [lǚyóu] - 	Tourism
# 游客    	 [yóu kè] - 	tourist,  visitor
# =========================
# 照相    	 [zhào xiàng] - 	take a picture,  take a photograph
# 相片    	 [xiàng piàn] - 	photo,  photograph
# 照片    	 [zhàopiàn] - 	Photo
# =========================
# 教练    	 [jiàoliàn] - 	coach
# 训练    	 [xùnliàn] - 	train
# 教训    	 [jiàoxùn] - 	lesson
# =========================
# 题目    	 [tímù] - 	subject
# 目标    	 [mùbiāo] - 	target
# 标题    	 [biāotí] - 	title,  heading
# =========================
# 能力    	 [nénglì] - 	ability
# 智力    	 [zhìlì] - 	intelligence
# 智能    	 [zhìnéng] - 	Intelligence
# =========================
# 建立    	 [jiànlì] - 	establish
# 建设    	 [jiànshè] - 	build
# 设立    	 [shèlì] - 	Establish
# =========================
# 父亲    	 [fùqīn] - 	father
# 母亲    	 [mǔqīn] - 	mother
# 父母    	 [fù mǔ] - 	father and mother,  parents
# =========================
# 亲切    	 [qīnqiè] - 	kind
# 亲密    	 [qīnmì] - 	close
# 密切    	 [mìqiè] - 	close
# =========================
# 男女    	 [nán nǚ] - 	men and women,  male and female
# 男士    	 [nán shì] - 	man
# 女士    	 [nǚshì] - 	Ma’am
