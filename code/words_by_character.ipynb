# %%
from functions import *

# %%
filename = '../data/HSK5/all_unique_words_with_tones.txt'
list_of_all_words = file_to_list_of_words(filename)
print_words_by_character_with_frequencies(list_of_all_words, lowest_frequency=2)
# Out:
# 固定    	 [gù dìng] - 	fixed (date of holiday)
#
# 上映    	 [shàng yìng] - 	released (about a movie)
#
# ...
# 3 上
# 上映    	 [shàng yìng] - 	released (about a movie)
# 跟上时代  	 [gēn shàng shídài] - 	updated, up to date
# 加上你 - plus you
# ...
# 3 动
# 分头行动  	 [fēn tóu xíng dòng] - 	separate actions
# 一项活动  	 [yī xiàng huó dòng] - 	an activity
# 动物表演 - animal show
# ...
# 3 爱
# 爱护植物 - to care about plants
# 兴趣爱好  	 [xìng qù ài hào] - 	hobby
# 爱惜    	 [ài xī] - 	cherish
# ...
# 3 达
# 达到    	 [dá dào] - 	achieve
# 达到目的 - achieve goals
# 欲速则不达 	 [yù sù zé bù dá] - 	haste makes waste
# ...
# 3 到
# 达到    	 [dá dào] - 	achieve
# 达到目的 - achieve goals
# 到处    	 [dào chù] - 	everywhere, throughout
# ...
# 3 道
# 胡说八道  	 [hú shuō bā dào] - 	nonsense, absurdity
# 频道    	 [pín dào] - 	channel, frequency
# 隧道    	 [suì dào] - 	tunnel
# ...
# 3 理
# 不理会   	 [bù lǐ huì] - 	ignore
# 理想的   	 [lǐ xiǎng de] - 	ideal
# 阅读理解  	 [yuè dú lǐ jiě] - 	reading comprehension
# ...
# 3 路
# 一段路   	 [yī duàn lù] - 	a road, a section of road
# ...
