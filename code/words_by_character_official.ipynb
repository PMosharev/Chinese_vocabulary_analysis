# %%
from functions import *

# %%
foldername = '../data/Official_HSK/'
from_level = 1
to_level = 5
filenames = create_filename_list(foldername=foldername, from_level=from_level, to_level=to_level)

# %%
list_of_all_words = []
for filename in filenames:
    list_of_all_words += csv_to_list_of_words(filename)

# %%
Lowest_frequency_to_show = 10
print('Vocabulary of HSK ' + str(from_level) + ' to ' + str(to_level) + ' contains ' + str(len(list_of_all_words)) + ' words.')
print_words_by_character_with_frequencies(list_of_all_words, lowest_frequency=Lowest_frequency_to_show)
# Out:
# Vocabulary of HSK 1 to 5 contains 4316 words.
# Total number of characters  1508
# ...
# Character  动  occurs in  74  unique words:
# 动画片   	 [dònghuàpiàn] - 	Cartoon
# 流动    	 [liú dòng] - 	flow,  run,  mobile
# 背（动）  	 [bēi] - 	carry on the back,  shoulder
# 封（动）  	 [fēng] - 	seal,  confer,  envelop
# 排（动）  	 [pái] - 	arrange,  put in order,  exclude,  rehearse
# 冲动    	 [chōngdòng] - 	impulse
# 动物园   	 [dòng wù yuán] - 	zoo
# 推动    	 [tuī dòng] - 	promote,  push forward,  give impetus to
# 称²（动） 	 [chēng] - 	call,  say,  name,  commend,  weigh
# 生动    	 [shēngdòng] - 	vivid
# 活动    	 [huódòng] - 	activity
# 举动    	 [jǔdòng] - 	Move
# 动人    	 [dòng rén] - 	moving,  touching
# 刻（动）  	 [kè] - 	carve,  engrave,  cut
# 移动    	 [yídòng] - 	move
# 关（动）  	 [guān] - 	shut,  close,  turn off
# 启动    	 [qǐ dòng] - 	switch on,  start
# 挺（动）  	 [tǐng] - 	stand,  hold out,  endure,  stick out
# 为（动）  	 [wéi] - 	act as,  become,  be,  mean
# 下（名、动）	 [xià] - 	below,  under,  next,  go down,  get off
# ...
